# %% [markdown]
# <H1 style="color:blue";> Introduction</H1>

# %% [markdown]
# <H2 style="color:blue";> BackGround </H2>
# <H4 style="color:blue";> Assuming a client is asking for advices of openning a restaurant in Toronto,</H4>
# <H4 style="color:blue";> 1.where to open it ?</H4>
# <H4 style="color:blue";> 2.what type of restaurant to open ?</H4>
# <H4 style="color:blue";>how do we find a proper answer for the client ? </H4>

# %% [markdown]
# <H1 style="color:blue";> Description of the data </H1>
# <H4 style="color:blue";>To answer that, we need collect some data, a Toronto dataset include:</H4>
# <H4 style="color:blue";> 1. "Postal Code" ,"Borough", "Neighborhood", Location("Lat", "Lng") of current restaurants</H4>
# <H4 style="color:blue";> 2. then analyze these data to find out what type of restaurants are there and how are they distributed in Toronto City</H4>
# <H4 style="color:blue";> Put these together, we can get some clue to decide where to open what type of restaurant</H4>

# %% [markdown]
# <H1 style="color:blue";> Methodology </H1>
# <H4 style="color:blue";> I will use 4square API to find out restaurant information and utilize the coursera module's Toronto neighbourhood data</H4>
# <H4 style="color:blue";> We can understand more clearly and straighforward after visualizing and tablizing our collected data</H4>
# <H4 style="color:blue";> by useing k-means to cluster the neighborhood into 5 clusters, we can see what type of restaurants are most popular in each cluster</H4>

# %% [markdown]
# <H1 style="color:blue";>Results </H1>

# %% [markdown]
# ![圖片.png](attachment:ead96bfe-6197-43d0-aba2-06686ff879a1.png)

# %% [markdown]
# ![圖片.png](attachment:d24d9b7d-9226-4083-a22e-f17034aef2e8.png)

# %% [markdown]
# ![圖片.png](attachment:b9170f1c-9050-41e8-9b1e-7252ca45542a.png)

# %% [markdown]
# ![圖片.png](attachment:6d94f786-4420-4e8d-9672-bd7f3cdd6bea.png)

# %% [markdown]
# ![圖片.png](attachment:f510f328-ec4c-45ab-8c79-ce335299e812.png)

# %% [markdown]
# ![圖片.png](attachment:3d0eb624-bcb5-4a36-91d8-44d97b3bd5f0.png)

# %% [markdown]
# <H1 style="color:blue";> Discussion & recommendations </H1>

# %% [markdown]
# <H3 style="color:blue";> Now we have cluster information of each neighbourhood and the ranking of the most common type of restaurants. In case you decide to open a restaurant in specific neighbourhood, then you can reference these cluster information to choose a proper type of restaurant.</H3>
# <H3 style="color:blue";> For example, in cluster 3,  the 1st and 2nd common restaurant are Middle Eastern restaurant, Brasilian restaurant, Vietnamese restaurant and sandwich place, then propbably you will not open a coffee shop here.</H3>
#
# <H3 style="color:blue";> And vice versa, if you decide to open a coffee shop, cluster 2 and cluster 5 neighbourhood maybe is your better choice.</H3>

# %% [markdown]
# <H1 style="color:blue";> Conclusion </H1>

# %% [markdown]
# <H3 style="color:blue";> These data analysis can give an overview of the current status of restaurants in Toronto to those people who would like to know. </H3>
# <H3 style="color:blue";> You can interpret these data in other way when you have other additional information. </H3>
